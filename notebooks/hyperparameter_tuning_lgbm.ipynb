# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append('..')

# %%
from rooms.model_creation import get_best_params
best_params = get_best_params()
# Out:
# 2024-12-31 10:43:48.538 | INFO     | rooms.data_processing:split_data:31 - df.shape=(2000, 3), train_pct=0.6, val_pct=0.3
# 2024-12-31 10:43:50.817 | INFO     | rooms.data_processing:create_features:99 - len(df)=1200 is_training=True ColumnNames.FEATURES=['cosine_similarity', 'levenshtein_distance', 'jaro_winkler_similarity', 'embedding_cosine_similarity']
# 2024-12-31 10:43:52.659 | INFO     | rooms.data_processing:create_features:99 - len(df)=599 is_training=False ColumnNames.FEATURES=['cosine_similarity', 'levenshtein_distance', 'jaro_winkler_similarity', 'embedding_cosine_similarity']
# [I 2024-12-31 10:43:53,396] A new study created in memory with name: no-name-82009f48-4691-4da2-9ba9-30bf72c00932
# feature_fraction, val_score: inf:   0%|                                                                                                                                       | 0/7 [00:00<?, ?it/s]
# [LightGBM] [Info] Number of positive: 607, number of negative: 593
# ...

# %%
best_params
# Out:
# {'objective': 'binary',
#  'metric': 'binary_logloss',
#  'boosting_type': 'gbdt',
#  'verbose': 1,
#  'random_state': 7,
#  'feature_pre_filter': False,
#  'lambda_l1': 1.833543386089636e-08,
#  'lambda_l2': 1.2657730280659832e-08,
#  'num_leaves': 2,
#  'feature_fraction': 1.0,
#  'bagging_fraction': 0.9421740075414173,
#  'bagging_freq': 3,
#  'min_child_samples': 20}
